# %% [markdown]
# ### Input table
# ##### Once a year
# converged-havas-de.converged_user.natrep_info
# (only needed to compute the SEC natrep - once a year)
# ##### Once a week
# converged-havas-de.converged_user.user_response_all_date
# converged-havas-de.converged_user.weight_all_date
# converged-havas-de.converged_user.codes_all_date
#
# ### Output table
# ##### Temp
# converged-havas-de.converged_user.btr_panelist_profile_fr
# ##### Result of the script
# converged-havas-de.converged_user.respondents_weights

# %% [markdown]
# ## Import Library

# %%
install.packages("anesrake")
install.packages("bigrquery")
install.packages("data.table")
install.packages("googleCloudStorageR")
install.packages("bigQueryR")
# Out:
# Installing package into ‘/opt/conda/anaconda/lib/R/library’
# (as ‘lib’ is unspecified)
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Installing package into ‘/opt/conda/anaconda/lib/R/library’
# (as ‘lib’ is unspecified)
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Installing package into ‘/opt/conda/anaconda/lib/R/library’
# (as ‘lib’ is unspecified)
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Installing package into ‘/opt/conda/anaconda/lib/R/library’
# (as ‘lib’ is unspecified)
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Installing package into ‘/opt/conda/anaconda/lib/R/library’
# (as ‘lib’ is unspecified)
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(bigrquery)
library(anesrake)
library("data.table")
library(googleCloudStorageR)
library(bigQueryR)
# Out:
# Loading required package: Hmisc
# Loading required package: lattice
# Loading required package: survival
# Loading required package: Formula
# Loading required package: ggplot2
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
#
# Attaching package: ‘Hmisc’
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units
#
# Loading required package: weights

# %%
gcs_global_bucket("converged-havas-de")
billing <- "converged-havas-de"
# Out:
# Set default bucket name to 'converged-havas-de'

# %%
bqr_auth(json_file = NULL, token = NULL, email = "converged-sa-user@converged-havas-de.iam.gserviceaccount.com")
# Out:
# ℹ 2021-06-04 09:38:39 > Setting client.id from options(googleAuthR.client_id)

# %%
projectId = "converged-havas-de"
datasetId = "converged_user"
tableId = "respondents_weight"

# %% [markdown]
# ## Create the targets (nat rep) variables
# ### For France  will use : Age, Gender, SEC and Location
# ##### The scope will be 18 to 69 yo, for France Metropolitan. Because we will not use all the YouGov Data (older panelist will be deleted and panelist who did not answer one of the weighting variable will be deleted), we need to INNER JOIN the output of the script with the RLD data to make sure we keep only the panelist we want (approx 95/96% of the panelists)
# ##### So we will need something to check each week the % of panelist lost to monitore it.
# ##### 41295558. In 2021, there is 41295558 people in France who have between 18 and 69 yo in France Metropolitan.

# %%
total_pop = 41295558

# %%
# Source : https://www.insee.fr/fr/statistiques/1893198
# File : modif FR demographics- Régions, genres, âges (2021-3)
# Scope : (18-69, France Metropolitain, 2021). 18 and 19 YO are restimated as 40% of the 15-19 category.
# RLD alias : pdl_gender
gender <- c(.51, .49)
names(gender) <- c("Female", "Male")
gender
# Out:
# Female   Male
#   0.51   0.49

# %%
# Source : https://www.insee.fr/fr/statistiques/1893198
# File : modif FR demographics- Régions, genres, âges (2021-3) 
# Scope : (18-69, France Metropolitain, 2021). 
# RLD alias : pdlc_agegrp
age <- c(.128, .181, .195, .206, .199, .091)
names(age) <- c("18-24", "25-34", "35-44", "45-54", "55-64", "65+")
age
# Out:
# 18-24 25-34 35-44 45-54 55-64   65+
# 0.128 0.181 0.195 0.206 0.199 0.091

# %% [raw]
# # After downloading the data :
# # Source : https://www.insee.fr/fr/statistiques/4995124?sommaire=2414232&q=Donn%C3%A9es+harmonis%C3%A9es+des+recensements#consulter
# # And import it to GCS, here is how to put it in BQ.
#
# from google.cloud import bigquery
#
# # Construct a BigQuery client object.
# client = bigquery.Client()
#
# # Set table_id to the ID of the table to create.
# table_id = "converged-havas-de.yougov_integration.natrep_info"
#
# job_config = bigquery.LoadJobConfig(
#     schema=[
#         bigquery.SchemaField("AN_RECENS", "STRING"),
#         bigquery.SchemaField("DEP_RES_19", "STRING"),
#         bigquery.SchemaField("DEP_NAIS", "STRING"),
#         bigquery.SchemaField("DEP_TRA_19", "STRING"),
#         bigquery.SchemaField("DEP_RAN_19", "STRING"),
#         bigquery.SchemaField("REG_RES_19", "STRING"),
#         bigquery.SchemaField("REG_NAIS", "STRING"),
#         bigquery.SchemaField("REG_TRA_19", "STRING"),
#         bigquery.SchemaField("REG_RAN_19", "STRING"),
#         bigquery.SchemaField("AGE_REV", "STRING"),
#         bigquery.SchemaField("SEXE", "STRING"),
#         bigquery.SchemaField("STAT_CONJ", "STRING"),
#         bigquery.SchemaField("NATIO", "STRING"),
#         bigquery.SchemaField("DIPL", "STRING"),
#         bigquery.SchemaField("TYP_ACT", "STRING"),
#         bigquery.SchemaField("NES4", "STRING"),
#         bigquery.SchemaField("CSP", "STRING"),
#         bigquery.SchemaField("POND", "STRING"),
#     ],
#     skip_leading_rows=1,
#     # The source format defaults to CSV, so the line below is optional.
#     source_format=bigquery.SourceFormat.CSV,
#     field_delimiter=';',
# )
# uri = "gs://converged-havas-user-de/data/warehouse/FD_RP_1968-2017.csv"
#
# load_job = client.load_table_from_uri(
#     uri, table_id, job_config=job_config
# )  # Make an API request.
#
# load_job.result()  # Waits for the job to complete.
#
# destination_table = client.get_table(table_id)  # Make an API request.
# print("Loaded {} rows.".format(destination_table.num_rows))

# %% [raw]
# #Python Query to compute the % of SEC for the natrep (not useful until update of the natrep)
# #Natrep could be updated once a year for each country
#
# from google.cloud import bigquery
# from google.cloud import bigquery_storage
#
# # Make clients.
# bqclient = bigquery.Client()
# bqstorageclient = bigquery_storage.BigQueryReadClient()
#
# csp_query = """
# #legacySQL
# SELECT
#   CSP,
#   ratio,
#   total,
#   ROUND(ratio * 100,2) AS new_weights
# FROM (
#   SELECT
#     (CASE
#         WHEN CSP = '1' THEN '2'
#       ELSE
#       CSP
#     END
#       ) AS CSP,
#     SUM(CAST(POND AS float)) AS total,
#     RATIO_TO_REPORT(total) OVER() AS ratio
#   FROM
#     [converged-havas-de:converged_user.natrep_info]
#   WHERE
#     AN_RECENS = '2017'
#     AND CAST(AGE_REV AS float) >= 18
#     AND CAST(AGE_REV AS float) < 70
#     AND CSP NOT IN ('01',
#       '02',
#       '03',
#       '04',
#       '94')
#   GROUP BY
#     CSP)"""
# query_config = bigquery.QueryJobConfig(use_legacy_sql=True)
#
# dataframe = (
#     bqclient.query(csp_query, job_config= query_config)
#     .result()
#     .to_dataframe(bqstorage_client=bqstorageclient)
# )
#
# csp_query1 = dataframe
# csp_query1

# %%
# Source : https://www.insee.fr/fr/statistiques/4995124?sommaire=2414232&q=Donn%C3%A9es+harmonis%C3%A9es+des+recensements#consulter
# File : [converged-havas-de:converged_user.natrep_info] Farmer added to Artisan, Retail & Entrepreneur to prevent low modality size
# Scope : (18-69, France Metropolitain, 2017). 
# RLD alias : pdl_Q_SEC
csp <- c(0.0538, 0.2037, 0.1178, 0.1458, 0.178, 0.1486, 0.1523)
names(csp) <- c("Artisan-Retail-Entrepreneur-Farmer", "Employee", "Executive and Intellectual profession", "Retired", "Intermediate occupation", "Other non-working", "Worker")
csp
# Out:
#    Artisan-Retail-Entrepreneur-Farmer                              Employee
#                                0.0538                                0.2037
# Executive and Intellectual profession                               Retired
#                                0.1178                                0.1458
#               Intermediate occupation                     Other non-working
#                                0.1780                                0.1486
#                                Worker
#                                0.1523

# %%
# Source : https://www.insee.fr/fr/statistiques/1893198
# File : modif FR demographics- Régions, genres, âges (2021-3)
# Scope : (18-69, France Metropolitain, 2021). 18 and 19 YO are restimated as 40% of the 15-19 category.
# RLD alias : pdlc_NEW_regions_2015
location <- c(.088, .092, .124, .042, .051, .038, .197, 0.091, 0.092,0.05, 0.058, 0.077)
names(location) <- c("Alsace,Champagne-Ardenne,Lorraine", "Aquitaine, Limousin, Poitou-Charentes", "Auvergne, Rhône-Alpes", "Bourgogne, Franche-Comté", "Bretagne", "Centre", "Ile-de-France", "Languedoc-Roussillon, Midi-Pyrénées", "Nord-Pas-de-Calais, Picardie", "Normandie", "Pays de la Loire", "Provence-Alpes-Côte")
location
# Out:
#     Alsace,Champagne-Ardenne,Lorraine Aquitaine, Limousin, Poitou-Charentes
#                                 0.088                                 0.092
#                 Auvergne, Rhône-Alpes              Bourgogne, Franche-Comté
#                                 0.124                                 0.042
#                              Bretagne                                Centre
#                                 0.051                                 0.038
#                         Ile-de-France   Languedoc-Roussillon, Midi-Pyrénées
#                                 0.197                                 0.091
#          Nord-Pas-de-Calais, Picardie                             Normandie
#                                 0.092                                 0.050
#                      Pays de la Loire                   Provence-Alpes-Côte
#                                 0.058                                 0.077

# %%
targets <- list(age,gender,location,csp)
names(targets) <- c('age','gender','location','csp')

# %%
# Natrep Targets
targets
# Out:
# $age
# 18-24 25-34 35-44 45-54 55-64   65+
# 0.128 0.181 0.195 0.206 0.199 0.091
#
# $gender
# Female   Male
#   0.51   0.49
#
# $location
#     Alsace,Champagne-Ardenne,Lorraine Aquitaine, Limousin, Poitou-Charentes
#                                 0.088                                 0.092
#                 Auvergne, Rhône-Alpes              Bourgogne, Franche-Comté
#                                 0.124                                 0.042
#                              Bretagne                                Centre
#                                 0.051                                 0.038
#                         Ile-de-France   Languedoc-Roussillon, Midi-Pyrénées
#                                 0.197                                 0.091
#          Nord-Pas-de-Calais, Picardie                             Normandie
#                                 0.092                                 0.050
#                      Pays de la Loire                   Provence-Alpes-Côte
#                                 0.058                                 0.077
#
# $csp
#    Artisan-Retail-Entrepreneur-Farmer                              Employee
#                                0.0538                                0.2037
# Executive and Intellectual profession                               Retired
#                                0.1178                                0.1458
#               Intermediate occupation                     Other non-working
#                                0.1780                                0.1486
#                                Worker
#                                0.1523

# %% [markdown]
# ## Creation of the dataset

# %%
sql <- "

CREATE OR REPLACE TABLE
  `converged-havas-de.converged_user.btr_panelist_profile_fr` AS (
  WITH
    sub AS (
    SELECT
      *
    FROM
      `converged-havas-de.converged_user.user_response_all_date`
    WHERE
      date=DATE(data.date)
      AND country_id = 7
      AND alias IN ('pdlc_agegrp',
        'pdlc_age',
        'pdl_gender',
        'pdlc_NEW_regions_2015',
        'pdl_Q_SEC') )
  SELECT
    weight.*,
    age.age,
    gender.gender,
    location.location,
    csp.csp
  FROM (
    SELECT
      country_id,
      date,
      yougov_id,
      CAST(response AS float64) AS weight
    FROM
      `converged-havas-de.converged_user.weight_all_date`
    WHERE
      CAST(date AS string) = data.date
      AND country_id = 7) AS weight
  INNER JOIN (
    SELECT
      country_id,
      date,
      yougov_id,
      name AS age
    FROM (
      SELECT
        response.*,
        codes.name
      FROM
        sub AS response
      INNER JOIN
        `converged-havas-de.converged_user.codes_all_date` AS codes
      ON
        response.country_id=codes.country_id
        AND response.alias = codes.definition_alias
        AND response.response = codes.value
      WHERE
        CAST(response.date AS string) = data.date
        AND response.country_id = 7
        AND response.alias = 'pdlc_agegrp'
        AND CAST(codes.date AS string) = data.date
        AND codes.country_id = 7
        AND codes.definition_alias = 'pdlc_agegrp')) AS age
  ON
    weight.country_id=age.country_id
    AND weight.date= age.date
    AND weight.yougov_id=age.yougov_id
  INNER JOIN (
    SELECT
      country_id,
      date,
      yougov_id
    FROM (
      SELECT
        response.*
      FROM
        sub AS response
      WHERE
        CAST(response.date AS string) = data.date
        AND response.country_id = 7
        AND response.alias = 'pdlc_age'
        AND CAST(response.response AS float64) >=18.0
        AND CAST(response.response AS float64) <70.0)) AS scope
  ON
    weight.country_id=scope.country_id
    AND weight.date= scope.date
    AND weight.yougov_id=scope.yougov_id
  INNER JOIN (
    SELECT
      country_id,
      date,
      yougov_id,
      name AS gender
    FROM (
      SELECT
        response.*,
        codes.name
      FROM
        sub AS response
      INNER JOIN
        `converged-havas-de.converged_user.codes_all_date` AS codes
      ON
        response.country_id=codes.country_id
        AND response.alias = codes.definition_alias
        AND response.response = codes.value
      WHERE
        CAST(response.date AS string) = data.date
        AND response.country_id = 7
        AND response.alias = 'pdl_gender'
        AND CAST(codes.date AS string) = data.date
        AND codes.country_id = 7
        AND codes.definition_alias = 'pdl_gender')) AS gender
  ON
    weight.country_id=gender.country_id
    AND weight.date= gender.date
    AND weight.yougov_id=gender.yougov_id
  INNER JOIN (
    SELECT
      country_id,
      date,
      yougov_id,
      name AS location
    FROM (
      SELECT
        response.*,
        codes.name
      FROM
        sub AS response
      INNER JOIN
        `converged-havas-de.converged_user.codes_all_date` AS codes
      ON
        response.country_id=codes.country_id
        AND response.alias = codes.definition_alias
        AND response.response = codes.value
      WHERE
        CAST(response.date AS string) = data.date
        AND response.country_id = 7
        AND response.alias IN ('pdlc_NEW_regions_2015')
        AND CAST(codes.date AS string) = data.date
        AND codes.country_id = 7
        AND codes.definition_alias IN ('pdlc_NEW_regions_2015') )) AS location
  ON
    weight.country_id=location.country_id
    AND weight.date= location.date
    AND weight.yougov_id=location.yougov_id
  INNER JOIN (
    SELECT
      country_id,
      date,
      yougov_id,
      name AS csp
    FROM (
      SELECT
        response.*,
        codes.name
      FROM
        sub AS response
      INNER JOIN
        `converged-havas-de.converged_user.codes_all_date` AS codes
      ON
        response.country_id=codes.country_id
        AND response.alias = codes.definition_alias
        AND response.response = codes.value
      WHERE
        CAST(response.date AS string) = data.date
        AND response.country_id = 7
        AND response.alias = 'pdl_Q_SEC'
        AND CAST(codes.date AS string) = data.date
        AND codes.country_id = 7
        AND codes.definition_alias = 'pdl_Q_SEC')) AS csp
  ON
    weight.country_id=csp.country_id
    AND weight.date= csp.date
    AND weight.yougov_id=csp.yougov_id )

"

# %%
th0 <- bq_project_query(billing, sql)
df0 <- bq_table_download(th0)

# %% [markdown]
# ## Pre process the data

# %%
sql <- "

SELECT
  yougov_id,
  age,
  gender,
  location,
  (CASE
      WHEN csp IN('Artisan-Retail-Entrepreneur', 'Farmer')THEN 'Artisan-Retail-Entrepreneur-Farmer'
    ELSE
    csp
  END
    ) AS csp
FROM
  converged-havas-de.converged_user.btr_panelist_profile_fr
WHERE
  date = DATE(data.date)
  AND country_id = 7
  AND age IS NOT NULL
  AND gender IS NOT NULL
  AND location IS NOT NULL
  AND csp IS NOT NULL

"

# %%
th <- bq_project_query(billing, sql)
df <- bq_table_download(th)

# %% [markdown]
# ## Prepare the ANES rank

# %%
df <- as.data.frame(df)

# %% [markdown]
# ## Apply the ANES rank

# %%
df$yougov_id <- as.factor(df$yougov_id) 
df$age <- as.factor(df$age) 
df$gender <- as.factor(df$gender) 
df$location <- as.factor(df$location) 
df$csp <- as.factor(df$csp)

# %%
outsave <- anesrake(targets, df, caseid=df$yougov_id, weightvec = NULL , 
cap = 5,
verbose = TRUE, maxit = 1000, type = "nolim", #all variables listed will be included in the weighting to make sure we will have the same weighting method between weeks
pctlim = 5, nlim = 5, filter = 1, choosemethod = "total",
iterate = TRUE, convcrit = 0.01, force1=TRUE, center.baseweights=TRUE)

#Good to know : Passek propose a function called anesrakefinder to find the variables we should used for weighting. For our case it is not helpful, we want to choose our variables.
# Out:
# [1] "Raking...Iteration 1"
# [1] "Capping...Iteration 1.1"
# [1] "Capping...Iteration 1.2"
# [1] "Capping...Iteration 1.3"
# [1] "Current iteration changed total weights by 72872.0961866228"
# [1] "Raking...Iteration 2"
# [1] "Capping...Iteration 2.1"
# [1] "Current iteration changed total weights by 8583.6961270142"
# [1] "Raking...Iteration 3"
# [1] "Current iteration changed total weights by 1094.64589646411"
# [1] "Raking...Iteration 4"
# [1] "Current iteration changed total weights by 459.477702998629"
# [1] "Raking...Iteration 5"
# [1] "Current iteration changed total weights by 212.740347635988"
# [1] "Raking...Iteration 6"
# [1] "Current iteration changed total weights by 98.3172625378296"
# [1] "Raking...Iteration 7"
# [1] "Current iteration changed total weights by 45.3668225798492"
# [1] "Raking...Iteration 8"
# [1] "Current iteration changed total weights by 20.920351813245"
# [1] "Raking...Iteration 9"
# [1] "Current iteration changed total weights by 9.64444433981985"
# [1] "Raking...Iteration 10"
# [1] "Current iteration changed total weights by 4.44559316464802"
# [1] "Raking...Iteration 11"
# [1] "Current iteration changed total weights by 2.04906916212654"
# [1] "Raking...Iteration 12"
# [1] "Current iteration changed total weights by 0.944434247750333"
# [1] "Raking...Iteration 13"
# [1] "Current iteration changed total weights by 0.435292720079958"
# [1] "Raking...Iteration 14"
# [1] "Current iteration changed total weights by 0.200626629241093"
# [1] "Raking...Iteration 15"
# [1] "Current iteration changed total weights by 0.0924686665761255"
# [1] "Raking...Iteration 16"
# [1] "Current iteration changed total weights by 0.0426186885333937"
# [1] "Raking...Iteration 17"
# [1] "Current iteration changed total weights by 0.0196428872100763"
# [1] "Raking...Iteration 18"
# [1] "Current iteration changed total weights by 0.00905337378702681"
# [1] "Raking...Iteration 19"
# [1] "Current iteration changed total weights by 0.00417268429624307"
# [1] "Raking...Iteration 20"
# [1] "Current iteration changed total weights by 0.00192318284839216"
# [1] "Raking...Iteration 21"
# [1] "Current iteration changed total weights by 0.000886391539122122"
# [1] "Raking...Iteration 22"
# [1] "Current iteration changed total weights by 0.000408536291681361"
# [1] "Raking...Iteration 23"
# [1] "Current iteration changed total weights by 0.000188293662653272"
# [1] "Raking...Iteration 24"
# [1] "Current iteration changed total weights by 8.67842050642498e-05"
# [1] "Raking...Iteration 25"
# [1] "Current iteration changed total weights by 3.99986747584569e-05"
# [1] "Raking...Iteration 26"
# [1] "Current iteration changed total weights by 1.84353251804215e-05"
# [1] "Raking...Iteration 27"
# [1] "Current iteration changed total weights by 8.49680287373644e-06"
# [1] "Raking...Iteration 28"
# [1] "Current iteration changed total weights by 3.91620238587853e-06"
# [1] "Raking...Iteration 29"
# [1] "Current iteration changed total weights by 1.80494539531173e-06"
# [1] "Raking...Iteration 30"
# [1] "Current iteration changed total weights by 8.31909229281891e-07"
# [1] "Raking...Iteration 31"
# [1] "Current iteration changed total weights by 3.83434426043383e-07"
# [1] "Raking...Iteration 32"
# [1] "Current iteration changed total weights by 1.76705712784386e-07"
# [1] "Raking...Iteration 33"
# [1] "Current iteration changed total weights by 8.14530087822618e-08"
# [1] "Raking...Iteration 34"
# [1] "Current iteration changed total weights by 3.75499777383048e-08"
# [1] "Raking...Iteration 35"
# [1] "Current iteration changed total weights by 1.73198940189856e-08"
# [1] "Raking...Iteration 36"
# [1] "Current iteration changed total weights by 7.99608174117949e-09"
# [1] "Raking...Iteration 37"
# [1] "Current iteration changed total weights by 3.68519886828622e-09"
# [1] "Raking...Iteration 38"
# [1] "Current iteration changed total weights by 1.7002693697421e-09"
# [1] "Raking...Iteration 39"
# [1] "Current iteration changed total weights by 7.76000985691638e-10"
# [1] "Raking...Iteration 40"
# [1] "Current iteration changed total weights by 3.7047803713719e-10"
# [1] "Raking...Iteration 41"
# [1] "Current iteration changed total weights by 1.83142057075258e-10"
# [1] "Raking...Iteration 42"
# [1] "Current iteration changed total weights by 8.59297077937526e-11"
# [1] "Raking...Iteration 43"
# [1] "Current iteration changed total weights by 3.77670117401863e-11"
# [1] "Raking...Iteration 44"
# [1] "Current iteration changed total weights by 2.17534878999004e-11"
# [1] "Raking...Iteration 45"
# [1] "Current iteration changed total weights by 1.49614765021511e-11"
# [1] "Raking...Iteration 46"
# [1] "Current iteration changed total weights by 1.49589785003457e-11"
# [1] "Raking converged in 46 iterations"

# %%
caseweights <- data.frame(cases=outsave$caseid, weights=outsave$weightvec)
head(caseweights)
# Out:
#                            cases                      weights
# 45JVIBPPFXEYI3GLUWBQXILQPI 45JVIBPPFXEYI3GLUWBQXILQPI 3.407399
# N34OBU74M4CBIE757Y4WQ55NEI N34OBU74M4CBIE757Y4WQ55NEI 1.180232
# S6V4ZS5BJIAFGZPBORGDL7EIGY S6V4ZS5BJIAFGZPBORGDL7EIGY 1.799251
# NJOJ4UXYKSCF7JMQNFH7RCRIBQ NJOJ4UXYKSCF7JMQNFH7RCRIBQ 1.799251
# 66BQSUG2Q3XEMXIOYYNGEPTIDE 66BQSUG2Q3XEMXIOYYNGEPTIDE 1.799251
# BBGMPGMXE2COKGDFFBFTRAUZKI BBGMPGMXE2COKGDFFBFTRAUZKI 1.799251

# %%
summary(outsave)
# Out:
# $convergence
# [1] "Complete convergence was achieved after 46 iterations"
#
# $base.weights
# [1] "No Base Weights Were Used"
#
# $raking.variables
# [1] "age"      "gender"   "location" "csp"
#
# $weight.summary
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.3016  0.4257  0.7677  1.0000  1.2059  4.9720
#
# $selection.method
# [1] "variable selection conducted using _nolim_ - discrepancies selected using _total_."
#
# $general.design.effect
# [1] 1.686021
#
# $age
#       Target Unweighted N Unweighted %     Wtd N Wtd % Change in % Resid. Disc.
# 18-24  0.128        18153   0.15165287  15321.73 0.128 -0.02365287 0.000000e+00
# 25-34  0.181        29109   0.24318093  21665.88 0.181 -0.06218093 2.775558e-17
# 35-44  0.195        29179   0.24376572  23341.70 0.195 -0.04876572 2.775558e-17
# 45-54  0.206        22064   0.18432595  24658.41 0.206  0.02167405 0.000000e+00
# 55-64  0.199        15830   0.13224618  23820.50 0.199  0.06675382 0.000000e+00
# 65+    0.091         5366   0.04482836  10892.79 0.091  0.04617164 0.000000e+00
# Total  1.000       119701   1.00000000 119701.00 1.000  0.26919902 5.551115e-17
#       Orig. Disc.
# 18-24 -0.02365287
# 25-34 -0.06218093
# 35-44 -0.04876572
# 45-54  0.02167405
# 55-64  0.06675382
# 65+    0.04617164
# Total  0.26919902
#
# $gender
#        Target Unweighted N Unweighted %     Wtd N Wtd % Change in %
# Female   0.51        90078     0.752525  61047.51  0.51  -0.2425250
# Male     0.49        29623     0.247475  58653.49  0.49   0.2425250
# Total    1.00       119701     1.000000 119701.00  1.00   0.4850501
#        Resid. Disc. Orig. Disc.
# Female 1.110223e-16  -0.2425250
# Male   0.000000e+00   0.2425250
# Total  1.110223e-16   0.4850501
#
# $location
#                                       Target Unweighted N Unweighted %
# Alsace,Champagne-Ardenne,Lorraine      0.088         9693   0.08097677
# Aquitaine, Limousin, Poitou-Charentes  0.092        11137   0.09304016
# Auvergne, Rhône-Alpes                  0.124        14220   0.11879600
# Bourgogne, Franche-Comté               0.042         3959   0.03307408
# Bretagne                               0.051         6015   0.05025021
# Centre                                 0.038         5072   0.04237224
# Ile-de-France                          0.197        22778   0.19029081
# Languedoc-Roussillon, Midi-Pyrénées    0.091        10918   0.09121060
# Nord-Pas-de-Calais, Picardie           0.092        12876   0.10756802
# Normandie                              0.050         7300   0.06098529
# Pays de la Loire                       0.058         6826   0.05702542
# Provence-Alpes-Côte                    0.077         8907   0.07441041
# Total                                  1.000       119701   1.00000000
#                                            Wtd N Wtd %   Change in %
# Alsace,Champagne-Ardenne,Lorraine      10533.688 0.088  0.0070232329
# Aquitaine, Limousin, Poitou-Charentes  11012.492 0.092 -0.0010401584
# Auvergne, Rhône-Alpes                  14842.924 0.124  0.0052040000
# Bourgogne, Franche-Comté                5027.442 0.042  0.0089259238
# Bretagne                                6104.751 0.051  0.0007497932
# Centre                                  4548.638 0.038 -0.0043722442
# Ile-de-France                          23581.097 0.197  0.0067091921
# Languedoc-Roussillon, Midi-Pyrénées    10892.791 0.091 -0.0002105997
# Nord-Pas-de-Calais, Picardie           11012.492 0.092 -0.0155680237
# Normandie                               5985.050 0.050 -0.0109852883
# Pays de la Loire                        6942.658 0.058  0.0009745783
# Provence-Alpes-Côte                     9216.977 0.077  0.0025895941
# Total                                 119701.000 1.000  0.0643526286
#                                       Resid. Disc.   Orig. Disc.
# Alsace,Champagne-Ardenne,Lorraine     1.387779e-17  0.0070232329
# Aquitaine, Limousin, Poitou-Charentes 0.000000e+00 -0.0010401584
# Auvergne, Rhône-Alpes                 1.387779e-17  0.0052040000
# Bourgogne, Franche-Comté              0.000000e+00  0.0089259238
# Bretagne                              0.000000e+00  0.0007497932
# Centre                                6.938894e-18 -0.0043722442
# Ile-de-France                         0.000000e+00  0.0067091921
# Languedoc-Roussillon, Midi-Pyrénées   0.000000e+00 -0.0002105997
# Nord-Pas-de-Calais, Picardie          0.000000e+00 -0.0155680237
# Normandie                             0.000000e+00 -0.0109852883
# Pays de la Loire                      0.000000e+00  0.0009745783
# Provence-Alpes-Côte                   0.000000e+00  0.0025895941
# Total                                 3.469447e-17  0.0643526286
#
# $csp
#                                       Target Unweighted N Unweighted %
# Artisan-Retail-Entrepreneur-Farmer    0.0538         9456   0.07899683
# Employee                              0.2037        46281   0.38663837
# Executive and Intellectual profession 0.1178        16401   0.13701640
# Intermediate occupation               0.1780         8861   0.07402612
# Other non-working                     0.1486        15082   0.12599728
# Retired                               0.1458        11158   0.09321560
# Worker                                0.1523        12462   0.10410941
# Total                                 1.0000       119701   1.00000000
#                                            Wtd N  Wtd % Change in %
# Artisan-Retail-Entrepreneur-Farmer      6439.914 0.0538 -0.02519683
# Employee                               24383.094 0.2037 -0.18293837
# Executive and Intellectual profession  14100.778 0.1178 -0.01921640
# Intermediate occupation                21306.778 0.1780  0.10397388
# Other non-working                      17787.569 0.1486  0.02260272
# Retired                                17452.406 0.1458  0.05258440
# Worker                                 18230.462 0.1523  0.04819059
# Total                                 119701.000 1.0000  0.45470321
#                                        Resid. Disc. Orig. Disc.
# Artisan-Retail-Entrepreneur-Farmer     0.000000e+00 -0.02519683
# Employee                               0.000000e+00 -0.18293837
# Executive and Intellectual profession -1.387779e-17 -0.01921640
# Intermediate occupation                0.000000e+00  0.10397388
# Other non-working                      0.000000e+00  0.02260272
# Retired                               -2.775558e-17  0.05258440
# Worker                                 0.000000e+00  0.04819059
# Total                                  4.163336e-17  0.45470321

# %%
caseweights$country_id <- '7'
caseweights$date <- '2022-01-06'

# %%
names(caseweights)[names(caseweights) == 'cases'] <- 'yougov_id'

# %%
names(caseweights)[names(caseweights) == 'weights'] <- 'weight'

# %%
data_all = caseweights
head(data_all)
# Out:
#                            yougov_id                  weight   country_id
# 45JVIBPPFXEYI3GLUWBQXILQPI 45JVIBPPFXEYI3GLUWBQXILQPI 3.407399 7
# N34OBU74M4CBIE757Y4WQ55NEI N34OBU74M4CBIE757Y4WQ55NEI 1.180232 7
# S6V4ZS5BJIAFGZPBORGDL7EIGY S6V4ZS5BJIAFGZPBORGDL7EIGY 1.799251 7
# NJOJ4UXYKSCF7JMQNFH7RCRIBQ NJOJ4UXYKSCF7JMQNFH7RCRIBQ 1.799251 7
# 66BQSUG2Q3XEMXIOYYNGEPTIDE 66BQSUG2Q3XEMXIOYYNGEPTIDE 1.799251 7
# BBGMPGMXE2COKGDFFBFTRAUZKI BBGMPGMXE2COKGDFFBFTRAUZKI 1.799251 7
#                            date
# 45JVIBPPFXEYI3GLUWBQXILQPI 2021-04-18
# N34OBU74M4CBIE757Y4WQ55NEI 2021-04-18
# S6V4ZS5BJIAFGZPBORGDL7EIGY 2021-04-18
# NJOJ4UXYKSCF7JMQNFH7RCRIBQ 2021-04-18
# 66BQSUG2Q3XEMXIOYYNGEPTIDE 2021-04-18
# BBGMPGMXE2COKGDFFBFTRAUZKI 2021-04-18

# %% [markdown]
# # Export the new weight for FR in BQ

# %%
## custom upload function to ignore quotes and column headers
f <- function(input, output) {
write.table(input, sep = ",", col.names = FALSE, row.names = FALSE, 
           quote = FALSE, file = output, qmethod = "double")}

# %%
## create the schema of the files you just uploaded
user_schema <- schema_fields(data_all)

# %%
bqr_upload_data(projectId = projectId, 
                datasetId = datasetId, 
                tableId = tableId, 
                upload_data = data_all,
                schema = user_schema)
# Out:
# 2021-06-04 09:39:05 -- Uploading local data.frame
# 2021-06-04 09:39:07 -- Upload job made...
# 2021-06-04 09:39:12 -- Waiting for job: job_-YzQ0UtQ6Dy73S4WCqTzbxMvkN97 - Job timer: 5.001389 secs
# ℹ 2021-06-04 09:39:12 > Request Status Code:  404
# Error: API returned: Not found: Job converged-havas-de:job_-YzQ0UtQ6Dy73S4WCqTzbxMvkN97
# Traceback:
#
# 1. bqr_upload_data(projectId = projectId, datasetId = datasetId,
#  .     tableId = tableId, upload_data = data_all, schema = user_schema)
# 2. bqr_do_upload(upload_data = upload_data, projectId = projectId,
#  .     datasetId = datasetId, tableId = tableId, create = create,
#  .     writeDisposition = writeDisposition, schema = schema, sourceFormat = sourceFormat,
#  .     wait = wait, autodetect = autodetect, nullMarker = nullMarker,
#  .     maxBadRecords = maxBadRecords, allowJaggedRows = allowJaggedRows,
#  .     allowQuotedNewlines = allowQuotedNewlines, fieldDelimiter = fieldDelimiter)
# 3. bqr_do_upload.data.frame(upload_data = upload_data, projectId = projectId,
#  .     datasetId = datasetId, tableId = tableId, create = create,
#  .     writeDisposition = writeDisposition, schema = schema, sourceFormat = sourceFormat,
#  .     wait = wait, autodetect = autodetect, nullMarker = nullMarker,
#  .     maxBadRecords = maxBadRecords, allowJaggedRows = allowJaggedRows,
#  .     allowQuotedNewlines = allowQuotedNewlines, fieldDelimiter = fieldDelimiter)
# 4. check_req(req, wait = wait)
# 5. bqr_wait_for_job(as.job(req$content))
# 6. bqr_get_job(projectId = job$jobReference$projectId, jobId = job$jobReference$jobId)
# 7. job(path_arguments = list(projects = projectId, jobs = jobId))
# 8. doHttrRequest(req_url, shiny_access_token = shiny_access_token,
#  .     request_type = http_header, the_body = the_body, customConfig = customConfig,
#  .     simplifyVector = simplifyVector)
# 9. checkGoogleAPIError(req)
# 10. stop("API returned: ", error_message, call. = FALSE)
